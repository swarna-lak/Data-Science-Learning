# %%
a=20
b=10
print ("Addition",a+b)
print ("Subtration",a-b)
print ("Multiplication",a*b)
print ("Division",a/b)
# Out:
# Addition 30
# Subtration 10
# Multiplication 200
# Division 2.0

# %%
num=19
if num%2==0:
    print(num,"even")
else:
    print(num,"odd")
# Out:
# 19 odd

# %%
a=50
b=90
if a>b:
    print(a,"is the largest number")
else:
    print(b,"is the largest number")
# Out:
# 90 is the largest number

# %%
t="Data Science"
rt=t[::-1]
print("Reverse string is",rt)
# Out:
# Reverse string is ecneicS ataD

# %%
t="Artificial Intelligence"
count=0
for letter in t.lower():
    if letter in "aeiou":
        count+=1
print("Number of vowels:",count)
# Out:
# Number of vowels: 10

# %%
num=[1,3,4,5,6,8]
num.append(10)
print("Updated list is",num)
# Out:
# Updated list is [1, 3, 4, 5, 6, 8, 10]

# %%
num=[1,3,4,5,6,8]
total=sum(num)
print("sum:",total)
# Out:
# sum: 27

# %%
colors=("Red","Blue","Green")
print(colors)
# Out:
# ('Red', 'Blue', 'Green')

# %%
num={1,2,3,4,5}
print(num)
# Out:
# {1, 2, 3, 4, 5}

# %%
t="python programming"
print(t.upper())
# Out:
# PYTHON PROGRAMMING

# %%
t="Machine Learning"
print("Length:",len(t))
# Out:
# Length: 16

# %%
p=1000
r=5
t=2
si=(p*r*t)/100
print("Simple Interest:",si)
# Out:
# Simple Interest: 100.0

# %%
a=10
b=20
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %%
for i in range(1,6):
    print("Square of",i,"=",i*i)
# Out:
# Square of 1 = 1
# Square of 2 = 4
# Square of 3 = 9
# Square of 4 = 16
# Square of 5 = 25

# %%
num=[10,20,30]
avg=sum(num)/len(num)
print("Average:",avg)
# Out:
# Average: 20.0

# %%
celsius=37
fahrenheit=(celsius* 9/5) +32
print("Tem in fahrenheit:",fahrenheit)
# Out:
# Tem in fahrenheit: 98.6

# %%
num=[1,1,2,3,3,4,5,6,6]
rm=list(set(num))
print("list after removing duplicates:")
print(rm)
# Out:
# list after removing duplicates:
# [1, 2, 3, 4, 5, 6]

# %%
num=[14,35,56,80]
print("Maximum number is",num)
# Out:
# Maximum number is [14, 35, 56, 80]

# %%
year=2026
if(year%400 ==0):
    print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2026 is not a leap year

# %%
r=5
area=3.14*r*r
print("Area of Circle:",area)
# Out:
# Area of Circle: 78.5
