# %%
import pandas as pd
sales_data=pd.read_csv("C:/Users/ashak/OneDrive/Desktop/swarna/summary.csv")
print("sales dataset",sales_data)
summary={
    "total sales":sales_data["Sales"].sum(),
    "total profit":sales_data["Profit"].sum(),
    "average sales":sales_data["Sales"].mean(),
    "avaerage profit":sales_data["Profit"].mean(),
    "maximun sales":sales_data["Sales"].max(),
    "minimun sales":sales_data["Sales"].min(),
    "total quantity sold":sales_data["Quantity"].sum(),
    "top product by sales":sales_data.groupby("Product")["Sales"].sum().idxmax(),
    "total regeion by sales":sales_data.groupby("Region")["Sales"].sum().idxmax(),
    "total electronic sales":
sales_data[sales_data["Category"]=="Electronics"]["Sal
.es"].sum(),
    "total electronic sales":
sales_data[sales_data["Category"]=="Furniture"]["Sales"].sum(),
    "highest profit":sales_data["Profit"].max(),
    "lowest profit":sales_data["Profit"].min(),
    "number of orders":sales_data["OrderID"].count(),
    "average quantity":sales_data["Quantity"].mean(),
}
summary_df=pd.DataFrame(summary.items(),
                        columns=["Question","answer"])
print("\nbussiness summary")
print(summary_df)
summary_df.to_csv("C:/Users/ashak/OneDrive/Desktop/swarna/business_summary.csv",index=False)
print("\nsummary exported successfully")
# Out:
# sales dataset    OrderID  Product     Category Region  Sales  Quantity  Profit
# 0     1001   Laptop  Electronics  South  50000         2    8000
# 1     1002    Phone  Electronics  North  20000         3    5000
# 2     1003   Tablet  Electronics   East  15000         1    3000
# 3     1004    Chair    Furniture   West   7000         4    1500
# 4     1005     Desk    Furniture  South  12000         2    2500
# 5     1006  Printer  Electronics  North  10000         1    2000
# 6     1007     Sofa    Furniture   East  25000         1    6000
# 7     1008  Monitor  Electronics   West  18000         2    4000
#
# bussiness summary
#                   Question   answer
# 0              total sales   157000
# 1             total profit    32000
# 2            average sales  19625.0
# 3          avaerage profit   4000.0
# 4            maximun sales    50000
# 5            minimun sales     7000
# 6      total quantity sold       16
# 7     top product by sales   Laptop
# ...
